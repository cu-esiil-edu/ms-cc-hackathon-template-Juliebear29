# %% [markdown]
# <a href="https://colab.research.google.com/github/cu-esiil-edu/ms-cc-hackathon-template-Juliebear29/blob/main/MS_CC_EDA.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import numpy as np
import pandas as pd
from matplotlib import pyplot as plt

# %%
data_dir = "/content/USW00013960.csv"
data = pd.read_csv(f"{data_dir}")

# %%
#Size of data
print(data.size)
print(data.shape)
data.head()
# Out:
# 113410
# (1031, 110)
#        STATION     DATE  LATITUDE  LONGITUDE  ELEVATION  \
# 0  USW00013960  1939-08  32.83839  -96.83583      147.6
# 1  USW00013960  1939-09  32.83839  -96.83583      147.6
# 2  USW00013960  1939-10  32.83839  -96.83583      147.6
# 3  USW00013960  1939-11  32.83839  -96.83583      147.6
# 4  USW00013960  1939-12  32.83839  -96.83583      147.6
#
#                         NAME  ADPT ADPT_ATTRIBUTES  ASLP ASLP_ATTRIBUTES  ...  \
# 0  DALLAS FAA AIRPORT, TX US   NaN             NaN   NaN             NaN  ...
# 1  DALLAS FAA AIRPORT, TX US   NaN             NaN   NaN             NaN  ...
# 2  DALLAS FAA AIRPORT, TX US   NaN             NaN   NaN             NaN  ...
# 3  DALLAS FAA AIRPORT, TX US   NaN             NaN   NaN             NaN  ...
# 4  DALLAS FAA AIRPORT, TX US   NaN             NaN   NaN             NaN  ...
#
#    WSF1 WSF1_ATTRIBUTES  WSF2 WSF2_ATTRIBUTES  WSF5 WSF5_ATTRIBUTES  WSFG  \
# ...

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1031 entries, 0 to 1030
# Columns: 110 entries, STATION to WSFM_ATTRIBUTES
# dtypes: float64(58), object(52)
# memory usage: 886.1+ KB

# %%
data.describe()
# Out:
#            LATITUDE     LONGITUDE     ELEVATION        ADPT         ASLP  \
# count  1.031000e+03  1.031000e+03  1.031000e+03  226.000000   226.000000
# mean   3.283839e+01 -9.683583e+01  1.476000e+02   11.223540  1015.924779
# std    4.691858e-13  7.108876e-14  2.871986e-12    7.243197     3.216376
# min    3.283839e+01 -9.683583e+01  1.476000e+02   -4.710000  1009.300000
# 25%    3.283839e+01 -9.683583e+01  1.476000e+02    4.775000  1013.600000
# 50%    3.283839e+01 -9.683583e+01  1.476000e+02   11.310000  1015.100000
# 75%    3.283839e+01 -9.683583e+01  1.476000e+02   18.262500  1018.500000
# max    3.283839e+01 -9.683583e+01  1.476000e+02   21.780000  1025.700000
#
#               ASTP        AWBT        AWND         CDSD         CLDD  ...  \
# count   226.000000  226.000000  326.000000  1023.000000  1029.000000  ...
# mean    998.515044   15.098496    4.135890   785.484848   135.196404  ...
# std       2.970110    6.662415    0.655416   684.517168   140.509856  ...
# ...
