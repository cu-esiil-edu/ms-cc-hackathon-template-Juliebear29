# %% [markdown]
# <a href="https://colab.research.google.com/github/cu-esiil-edu/ms-cc-hackathon-template-Juliebear29/blob/main/Project_details.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# #               ** Background Info**
# **Topic:** Understanding and predicting ecosystem disruption impacting mammals through machine learning models
#
# **Climatology:** The study of long-term weather patterns and climate change from local to global scales. Climatology is essential for the understanding of the impact of climate change on ecosystems and human societies. It determines the future climate expectations involving analyzing weather data and understanding the factors that influence climate.
#
# **Weather**
# * The atmospheric conditions in a specific place at a particular time, such as temperature, humidity, precipitation, wind speed, etc.
# * Examples: Thunderstorm, or a snowy
#
# **Climate**
# * The long-term average of weather patterns in a region over decades
# * Examples: The Sahara Desert has a hot, arid climate
#
# **What role do weather and climate play in ecosystems?**
#   Weather and climate influence the distribution and abundance of species, and the availability of resources. Some species are adapted to a warm climate, while others thrive in cold or dry areas.
#
# Examples: Polar bears depend on cold climates and sea ice to hunt seals
# Many mammals time their breeding and migration with seasonal climate patterns
#
#
# **Ecology**
# * The study of the interaction between living organisms and their environment, including both biotic (living) and abiotic (non-living) factors
#
# **Predation:** One organism (predator) hunts and eats another (prey).
#     Example: A lion eating a zebra.
#
# **Competition: **bold text** **Organisms compete for the same resources (food, space, mates).
#     Example: Trees competing for sunlight in a forest.
#
# **Mutualism:** Both species benefit from the relationship.
#     Example: Bees pollinating flowers while feeding on nectar.
#
# **Commensalism:** One species benefits while the other is neither helped nor harmed.
#     Example: Birds nesting in trees.
#
# **Parasitism:** One organism benefits (parasite) while the other is harmed (host).
#     Example: Ticks feeding on a mammal’s blood.
#
#
# **Disruption**
#
# * When something causes a disturbance or break in how an ecosystem normally works.
# * A wildfire that destroys a forest/Building a city where animals used to live.
#
# **What, how-mention and explain at least one example of an algorithm**
#
# *  AI (broad intelligence-like behaviors) and ML (models that learn from data)
# *  **An algorithum:** Random Forest: ensemble of decision trees, often used for regression or classification.
#
# **Work on explaining what a random forest is and how it's used**
#
#
#
#
# **AI/ML and applications to study Ecology&Disruption**
#
# * Use Random Forest to predict habitat changes from climate data.
#
#
# **Read through the literature and synthesize on the current studies in this area.**
#
# * read 3–5 papers on ML in ecological disruption and climate impacts.
#
# **Describe the process to use (methodology) for analyzing this data**
#
# * Data acquisition & cleaning — imports, handle missing values, feature engineering.
# * Exploratory Data Analysis (EDA) — visualize seasonal trends, correlations
# * Feature selection/creation — seasonal indicators, climate-derived variables, spatial features, etc.
# * Model selection — decide algorithm (e.g. Random Forest Regression/Classification). **write drifferent between Random Forest Regression/classification**
# * Training & validation strategy — train/test split, cross-validation, time-aware splits if needed.
# * Performance metrics — e.g. MAE, RMSE, accuracy, ROC‑AUC depending on the target.
#
# **Show the process learned so far (EDA, Applying ML model, Evaluation, Tuning) with the dataset.**
#
#                     ***Loading of data***
#                     import pandas as pd
#                     df = pd.read_csv('your_data.csv')
#
#                     ***handling missing values***
#                     df = df.fillna(method='ffill')
#
#                     **EDA**
#                     import seaborn as sns, matplotlib.pyplot as plt
#                     sns.pairplot(df[['temp', 'precip', 'target']])
#                     plt.show()
#
#                     **Engineering**
#                     df['month'] = pd.to_datetime(df['date']).dt.month
#
#                     **Modeling**
#                     from sklearn.ensemble import RandomForestRegressor
#                     model = RandomForestRegressor(n_estimators=100, random_state=42)
#
#                   **Evalution**
#                   from sklearn.model_selection import cross_val_score
#                   scores = cross_val_score(model, X, y, cv=5 scoring='neg_root_mean_squared_error')
#                     print("CV RMSE:", -scores.mean())
#
#               **Tuning**
#               from sklearn.model_selection import GridSearchCV
#               param_grid = {'n_estimators': [50, 100], 'max_depth': [None, 10, 20]} grid = GridSearchCV(model, param_grid, cv=3, scoring='neg_root_mean_squared_error')
#               grid.fit(X, y)
#               print("Best params:", grid.best_params_)
#
#
# **Summarize any conclusions drawn from this study and how it relates to the topics we've discussed this summer.**
#
# Through this study, I explored the intersection of ecology, climate, and machine learning using the PanTheria dataset and a Random Forest model. By applying exploratory data analysis and training a Random Forest model, I was able to identify significant relationships between climate variables,such as temperature and precipitation—and ecological traits of mammal species. These relationships provide early indicators of how environmental disruptions may influence species vulnerability and distribution.
#
# One of the most important takeaways from this work is how machine learning can uncover complex patterns in large ecological datasets that traditional statistical methods might overlook. Random Forest, for example, highlighted the predictive strength of climate-based features in assessing ecosystem risk, demonstrating the potential of AI to support conservation science and environmental monitoring.
#
# Moving forward, I would try more advanced models and include other data sources like satellite imagery. Overall, this research is a step toward leveraging machine learning not just to observe the impacts of climate change, but to better prepare for and respond to them.
